# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_excel('ProdClust.xlsx')

# %%
df.sort_values(by='well', inplace=True)

# %%
df
# Out:
#     cluster    well  2001-12-01 00:00:00  2002-01-01 00:00:00  \
# 34       C2     274                75.29                58.32
# 69       C3     276                37.48                38.14
# 6        C2     277                33.93                23.77
# 70       C3     278                18.64                19.83
# 125      C4     279               138.10               145.19
# 35       C2     280               122.53                97.90
# 86       C4     282               122.55                75.97
# 87       C4     288                75.70                62.90
# 88       C4     291                77.20                56.84
# 89       C4     292                49.09                39.52
# 21       C2     293                14.82               141.00
# 90       C4     294                99.93                91.37
# 91       C4     295                50.00                35.32
# 22       C2     297               125.90               119.33
# ...

# %%
df.shape
# Out:
# (138, 180)

# %%
f, ax = subplots(figsize=(16, 8))
cm = plt.cm.gist_ncar
len_months = 10 * 12
ax.set_color_cycle([cm(i) for i in np.linspace(0., 0.9, len_months)])
for month in xrange(len_months):
    df.plot.kde(y=df.columns[3+month], ax=ax, legend=False, alpha=0.5)
#     df.plot.hist(bins=20, histtype='step', y=df.columns[3+month], ax=ax, legend=False, alpha=0.5)

# %%
df[df['well'] == 274]
# Out:
#    cluster well  2001-12-01 00:00:00  2002-01-01 00:00:00  \
# 34      C2  274                75.29                58.32
#
#     2002-02-01 00:00:00  2002-03-01 00:00:00  2002-04-01 00:00:00  \
# 34                51.37                36.48                34.73
#
#     2002-05-01 00:00:00  2002-06-01 00:00:00  2002-07-01 00:00:00  \
# 34                30.87                27.71                24.13
#
#            ...           2015-12-01 00:00:00  2016-01-01 00:00:00  \
# 34         ...                           NaN                  NaN
#
#     2016-02-01 00:00:00  2016-03-01 00:00:00  2016-04-01 00:00:00  \
# 34                  NaN                  NaN                  NaN
#
#     2016-05-01 00:00:00  2016-06-01 00:00:00  2016-07-01 00:00:00  \
# 34                  NaN                  NaN                  NaN
#
#     2016-08-01 00:00:00  2016-09-01 00:00:00
# 34                  NaN                  NaN
#
# [1 rows x 180 columns]

# %%
df[df['well'] == 274].as_matrix()
# Out:
# array([[u'C2', 274, 75.29, 58.32, 51.37, 36.48, 34.73, 30.87, 27.71,
#         24.13, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
f, ax = subplots(figsize=(16, 6))

for well_index in xrange(138):
    df.iloc[well_index][2:5 * 12].plot(color='gray', alpha=0.5, style='-', ax=ax, 
                                 label=df.iloc[well_index]['well'])

# %%
df_water = pd.read_excel('ProdClust.xlsx', sheet_name=u'Water Cut (Обводненность)')

# %%
df_water.sort_values(by='well', inplace=True)

# %%
df_water
# Out:
#     clusters    well  2001-12-01 00:00:00  2002-01-01 00:00:00  \
# 137       C3       2                79.65                71.56
# 84        C2     274                22.11                29.48
# 7         C1     276                28.36                33.54
# 8         C1     277                32.84                32.56
# 9         C1     278                52.68                55.46
# 45        C2     279                15.64                 5.53
# 10        C1     280                46.74                35.68
# 46        C2     282                24.89                17.07
# 85        C2     288                56.94                50.82
# 0         C1     291                87.31                77.24
# 86        C2     292                53.85                55.59
# 11        C1     293                19.02                38.30
# 115       C3     294                15.34                 9.85
# 12        C1     295                83.60                64.93
# ...

# %%
df_water.shape
# Out:
# (138, 180)

# %%
f, ax = subplots(figsize=(16, 8))
cm = plt.cm.gist_ncar
len_months = 10 * 12
ax.set_color_cycle([cm(i) for i in np.linspace(0., 0.9, len_months)])
for month in xrange(len_months):
    df_water.plot.kde(y=df_water.columns[3+month], ax=ax, legend=False, alpha=0.5)

# %%
f, ax = subplots(figsize=(16, 6))

for well_index in xrange(138):
    df_water.iloc[well_index][2:10 * 12].plot(color='gray', alpha=0.5, style='-', ax=ax, 
                                             label=df_water.iloc[well_index]['well'])

# %%
df_2d = df.join(df_water, on='well', lsuffix='_liq', rsuffix='_wat')

# %%
# Out:
# array([18.81, 21.39, 11.85, 16.76, 14.33, 15.09, 14.0, 14.27, 15.53,
#        15.25, 12.78, 15.83, 10.28, 10.81, 12.83, 10.52, 9.87, 10.39,
#        10.53, 11.03, 9.76, 10.41, 10.53, 9.5, 9.8, 9.76, 9.89, 10.21,
#        11.23, 10.41, 0.0, 10.26, 11.47, 10.12, 10.47, 9.34, 10.46, 10.46,
#        8.95, 10.44, 10.37, 26.14, 18.97, 18.0, 16.87, 16.44, 15.79, 16.43,
#        17.11, 16.14, 15.91, 16.28, 13.81, 16.3, 15.1, 16.35, 18.67, 16.83,
#        16.43, 16.35, 14.54, 16.71, 17.25, 16.43, 18.52, 24.83, 23.29,
#        23.68, 22.46, 22.12, 19.98, 18.01, 13.02, 18.02, 21.78, 19.04,
#        19.9, 19.27, 19.86, 18.93, 18.16, 19.06, 22.51, 21.29, 20.64,
#        23.83, 28.32, 28.82, 25.43, 33.02, 35.14, 39.28, 37.6, 34.92,
#        34.65, 39.37, 45.51, 35.63, 34.39, 34.76, 35.67, 35.61, 36.47,
#        39.56, 35.68, 34.19, 33.19, 32.46, 36.79, 35.98, 35.66, 37.1,
#        38.43, 39.84, 41.85, 46.57, 44.03, 42.25], dtype=object)

# %%
f, ax = subplots(figsize=(16, 8))


for well_index in xrange(138):
    plot(df.iloc[well_index][2:10 * 12].values,
         df_water.iloc[well_index][2:10 * 12].values,
         '.', alpha=0.5, color='gray')

well = 1
plot(df.iloc[well][2:10 * 12].values,
     df_water.iloc[well][2:10 * 12].values,
     'o-', alpha=0.5, color='red')


ax.set_xlabel('Liquid rate')
ax.set_ylabel('Water cut')
# Out:
# Text(0,0.5,u'Water cut')
